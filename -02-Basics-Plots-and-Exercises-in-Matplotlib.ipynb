# %% [markdown]
# # **-02-Plot-Basics-in-Matplotlib**

# %% [markdown]
# © by A.Richter (under construction)
#
# <img src=88x31.png  width="10%" style="float: left;">

# %% [markdown]
# **Preface:** The Plot-library used in this examples is **matplotlib** (  https://matplotlib.org/ )
# Matplotlib has similar power as the commercial MATLAB plotting routines and is widely used as an open source alternative in the scientific community. There are several other libraries available like gnuplot, plotly, seaborn and many more ... which offer similar options. Here we will only focus on using matplotlib.
#
# References:
#
#  - https://www.fusioncharts.com/blog/best-python-data-visualization-libraries/
#
#  - https://mode.com/blog/python-data-visualization-libraries

# %% [markdown]
# ## Overview of the notebook:
#
#    1. [Plotting of 2D-Data in Singleplots](#2dplots)
#    2. [Plotting of 2D Coordinate lists](#coords)
#    3. [Plots arranged side-by-side or in a figure](#figure)
#    4. [Changing the size of a figure](#figuresize)
#    5. [Plotting of 3D-Data in Singleplots](#3dplots)
#    6. [Interactive Plots](#interactiveplots)

# %% [markdown]
# ## Plotting of 2D-Data in Singleplots <a name="2dplots" ></a>

# %% [markdown]
# matplotlib is imported by the lines below

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# where **plt** is used as an abreviation to save time in writing the source code. To make sure a diagram, an image or a plot is shown directly in the notebook below the code, the 'inline' parameter must be set:

# %%
# %matplotlib inline

# %% [markdown]
# In the following example random numbers are generated, assigend to a linear function and added with random gaussian noise

# %%
import numpy as np

# %% [markdown]
# The function **'plt.plot(x,y,'.b')'** is used with the paraters **'x:x-values'** at first and than **'y:y-values'** secondly assigned to the corresponding x and at third place the symbol used to display the datapoints in the plot, here a '.' means a small dot and '.b' specifies a small dot of color blue.

# %%
x=10*np.random.rand(20,1)   # uniform distributet samples between [0 ... 10]
y=6.3*x+15
plt.plot(x,y,'b.')
plt.show()

# %% [markdown]
# The plot shows a perfectly alligned line. So now I will add some confusion to the y data in form of small random variations and repeat the plot. Everytime I run the cell **'y'** will be updated.

# %%
y1=y+5*np.random.randn(20,1) # add random gaussian noise as random data errors
plt.plot(x,y1,'b.')
plt.show()

# %% [markdown]
# ## Plotting of 2D Coordinate lists <a name="coords" ></a>

# %% [markdown]
# given a world-coordinate list for example as [X-Value,Y-Value] I can produce a numeric python datastructure named 'CoordList' with np.array() and plots the data by specifying each column CoordList[:,0] and CoordList[:,1]

# %%
# import numpy as np
# from matplotlib import pyplot as plt
# %matplotlib inline                    
# arrange the plot output in the notebook

CoordList= np.array(
[[85305.32,  20253.65],
[ 84711.28,  20407.43],
[ 84099.75 , 19748.73],
[ 84602.53 , 19156.37],
[ 85145.76  ,19453.91]])

plt.plot(CoordList[:,0],CoordList[:,1],'ro')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# a legend can be added (label is mandatory for this ,e.g. **label='Coordinates'**) and the color can be easily changed

# %% [markdown]
# also a title can be added by the command: **plt.title('....')**

# %%
plt.plot(CoordList[:,0],CoordList[:,1],'bo', label='Coordinates')
plt.title('Plot of a coordinates list')
plt.legend()
#plt.show

# %% [markdown]
# ## Plots arranged side-by-side or in a figure <a name="figure" ></a>

# %% [markdown]
# if more than one plot is needed the functions  **figure()** and **subplot()** is needed

# %% [markdown]
# The numbering of the "subplot(221)" means a 2 by 2 grid (22x-> first two numbers and the index x of current subplot [1...4] )

# %% [markdown]
# More than one plot can be arranged by the use of the subplot routine.

# %%
# %matplotlib inline

x=10*np.random.rand(20,1)   # uniform distributet samples between [0...10]
y=6.3*x+15
y=y+10*np.random.randn(20,1)
x=np.ravel(x)
m,b=np.polyfit(x,y,1)
plt.plot(x,y,'ro')           # single plot 
plt.title('Random Points in single-plot')

plt.figure()   # figure with subplots
plt.subplot(221),plt.plot(x,y,'ro')
plt.title('Points')
plt.subplot(222),plt.plot(x,m*x+b,'b')
plt.title('Regression-line')
plt.subplot(223),plt.plot(x,y,'ro'),plt.plot(x,m*x+b,'b')
plt.title('Points and Regression-line')

#plt.show()
# Out:
# Text(0.5, 1.0, 'Points and Regression-line')

# %% [markdown]
# ## Changing the size of a figure <a name="figuresize" ></a>

# %%
plt.figure(figsize=(16,12))   # figure with subplots
plt.subplot(221),plt.plot(x,y,'ro')
plt.title('Points')
plt.subplot(222),plt.plot(x,m*x+b,'b')
plt.title('Regression-line')
plt.subplot(223),plt.plot(x,y,'ro'),plt.plot(x,m*x+b,'b')
plt.title('Points and Regression-line')
# Out:
# Text(0.5, 1.0, 'Points and Regression-line')

# %% [markdown]
# References:  https://astrofrog.github.io/py4sci/
#
# https://www.pythonforengineers.com/python-for-scientists-and-engineers/

# %% [markdown]
# ## Plotting of 3D-Data in Singleplots <a name="3dplots" ></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scripts.plot_2d_separator import plot_2d_separator
n=200
# normal distribution and ring around it
class_3 = 0.6 * np.random.randn(n,2)
r = 0.8 * np.random.randn(n,1) + 5
angle = 2*np.pi * np.random.randn(n,1)
class_4 = np.hstack((r*np.cos(angle),r*np.sin(angle))) 
labels_b = np.hstack((np.ones(n),-np.ones(n)))

plt.figure(figsize=(10,5))
plt.plot(class_3[:,0],class_3[:,1],'r.')
plt.plot(class_4[:,0],class_4[:,1],'b.')
plt.xlim(-10,10)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

x1=np.power(class_3[:,0],2)
y1=np.power(class_3[:,1],2)
z1=class_3[:,1]*class_3[:,1]


x2=np.power(class_4[:,0],2)
y2=np.power(class_4[:,1],2)
z2=class_4[:,1]*class_4[:,1]


fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')

ax.plot(x1, y1, z1,'r.', label='r')
ax.plot(x2, y2, z2,'b.', label='b')

ax.legend()
ax.view_init(elev=30., azim=-35)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# https://www.cambridge.org/core/books/python-for-scientists/E5CBE088065279A607A18673622AD89D

# %% [markdown]
# point plots are easy as we can see above
# for example let's plot a functions graph in 3D like a surface in space
#
# $$ z = e^{-2x^2-y^2}cos(2x)cos(3y)$$ with $$-2 \le x \le 2$$ and $$-3 \le y  \le3$$

# %%
x,y=np.mgrid[-2:2:81j, -3:3:91j]
z=np.exp(-2*x**2-y**2)*np.cos(2*x)*np.cos(3*y)

# %%
plt.ion()
fig=plt.figure(figsize=(10,10))
ax=Axes3D(fig)
ax.plot_surface(x,y,z,rstride=4,cstride=3,color='g',alpha=0.9)

ax.contour(x,y,z,zdir='x',offset=-3.0,colors='black')
ax.contour(x,y,z,zdir='y',offset=4.0,colors='black')
ax.contour(x,y,z,zdir='z',offset=-2.0,colors='black')

ax.set_xlim3d(-3.0,2.0)
ax.set_ylim3d(-3.0,4.0)
ax.set_zlim3d(-2.0,1.0)
# Out:
# (-2.0, 1.0)

# %%
'''
======================
Triangular 3D surfaces
======================

Plot a 3D surface with a triangular mesh.
'''

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

n_radii = 8
n_angles = 36

# Make radii and angles spaces (radius r=0 omitted to eliminate duplication).
radii = np.linspace(0.125, 1.0, n_radii)
angles = np.linspace(0, 2*np.pi, n_angles, endpoint=False)

# Repeat all angles for each radius.
angles = np.repeat(angles[..., np.newaxis], n_radii, axis=1)

# Convert polar (radii, angles) coords to cartesian (x, y) coords.
# (0, 0) is manually added at this stage,  so there will be no duplicate
# points in the (x, y) plane.
x = np.append(0, (radii*np.cos(angles)).flatten())
y = np.append(0, (radii*np.sin(angles)).flatten())

# Compute z to make the pringle surface.
z = np.sin(-x*y)

fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')

ax.plot_trisurf(x, y, z, linewidth=0.2, antialiased=True)

plt.show()

# %% [markdown]
# ## Interactive Plots <a name="interactiveplots" ></a>

# %%
# %matplotlib widget
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()

interact(update);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# interactive(children=(FloatSlider(value=1.0, description='w', max=3.0, min=-1.0), Output()), _dom_classes=('wi…
