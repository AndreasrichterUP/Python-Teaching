# %% [markdown]
# -02-Plot-Basics-and-Exercises-in-Matplotlib © by A.Richter
# ------------------------------------------

# %% [markdown]
# The Plot-library used in this examples is **matplotlib** (  https://matplotlib.org/ )

# %% [markdown]
# matplotlib is imported by the lines below

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# where **plt** is used as an abreviation.

# %% [markdown]
# to make sure a diagram, an image or a plot is shown directly in the notebook below the code, this line is used

# %%
# %matplotlib inline

# %% [markdown]
# Plotting of 2D-Data in Singleplots
# ===

# %% [markdown]
# In the following example random numbers are generated, assigend to a linear function and added with random gaussian noise

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x=10*np.random.rand(20,1)   # uniform distributet samples between [0 ... 10]
y=6.3*x+15
plt.plot(x,y,'b.')
plt.show

y1=y+5*np.random.randn(20,1) # add random gaussian noise as random data errors
plt.plot(x,y1,'b.')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **Plotting of 2D Coordinate lists**

# %% [markdown]
# given a coordinate list as [X-Value,Y-Value]
# with np.array() one makes an numeric Python datastructure C
# and plots the data by specifying each column C[:,0] and C[:,1]

# %%
# import numpy as np
# from matplotlib import pyplot as plt
# %matplotlib inline                    
# arrange the plot output in the notebook

CoordList= np.array(
[[85305.32,  20253.65],
[ 84711.28,  20407.43],
[ 84099.75 , 19748.73],
[ 84602.53 , 19156.37],
[ 85145.76  ,19453.91]])

plt.plot(CoordList[:,0],CoordList[:,1],'ro')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# a Legend can be added (label is mandatory,e.g. **label='Coordinates'**), the color can be easily changed

# %%
plt.plot(CoordList[:,0],CoordList[:,1],'bo', label='Coordinates')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# a title can be added by the command: **plt.title('....')**

# %%
plt.plot(CoordList[:,0],CoordList[:,1],'bo', label='Coordinates')
plt.title('Plot of a coordinates list')
plt.legend()
#plt.show

# %% [markdown]
# Plots can also be arranged side-by-side or in a grid
# ---

# %% [markdown]
# if more than one plot is needed the functions  **figure()** and **subplot()** is needed

# %% [markdown]
# The numbering of the "subplot(221)" means a 2 by 2 grid (22x-> first two numbers and the index x of current subplot [1...4] )

# %% [markdown]
# More than one plot can be arranged by the use of the subplot routine.

# %%
# %matplotlib inline

x=10*np.random.rand(20,1)   # uniform distributet samples between [0...10]
y=6.3*x+15
y=y+10*np.random.randn(20,1)
x=np.ravel(x)
m,b=np.polyfit(x,y,1)
plt.plot(x,y,'ro')           # single plot 
plt.title('Random Points in single-plot')

plt.figure(figsize=(16,12))   # figure with subplots
plt.subplot(221),plt.plot(x,y,'ro')
plt.title('Points')
plt.subplot(222),plt.plot(x,m*x+b,'b')
plt.title('Regression-line')
plt.subplot(223),plt.plot(x,y,'ro'),plt.plot(x,m*x+b,'b')
plt.title('Points and Regression-line')

#plt.show()

# %% [markdown]
# Imageplots - read image with OpenCV
# ---

# %% [markdown]
# if a different sort of data is processed for example images, a different function from plt has to be used...

# %% [markdown]
# to display image-data the function **plt.imshow()** is used

# %% [markdown]
# OpenCV has to be installed separately... e.g. by  **pip3 install opencv-python**

# %% [markdown]
# https://stackoverflow.com/questions/46610689/how-to-import-cv2-in-python3

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
img=cv2.imread('figures/doug.jpg',0)
plt.figure(figsize=(10,5))
plt.imshow(img, cmap = 'gray')
plt.show()

image=img
plt.figure(figsize=(20,10))  
plt.imshow(image)
plt.show()

#f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
#ax1.imshow(image[0:50,0:50,0:3])
#ax1.set_title('Details of the Scene')
#ax2.imshow(image[0:400,0:400,0:3])
#ax3.imshow(image[0:500,0:500,0:3])
#ax4.imshow(image[0:500,0:500,0:3])
#plt.show()

# %% [markdown]
# Imageplots - read an image with Skimage library (Scikit-Image)
# ---

# %% [markdown]
# To import image Data an image processing library like skimage can be used (there are more)

# %%
import skimage.io as skio

doug=skio.imread('figures/doug.jpg')    # read the imgage to a variable called "doug"

plt.imshow(doug, cmap = 'gray')         # show the image and assign a colormap
plt.show()

# %% [markdown]
# the origine of rows and cols is in the upper left corner

# %% [markdown]
# Basemap plots - plotting maps and GIS Data
# ---

# %%
#http://matplotlib.org/basemap/api/basemap_api.html
# %matplotlib inline
from mpl_toolkits.basemap import Basemap, shiftgrid, cm
import numpy as np
import matplotlib.pyplot as plt
#from netCDF4 import Dataset

# read in etopo5 topography/bathymetry.
#url = 'http://ferret.pmel.noaa.gov/thredds/dodsC/data/PMEL/etopo5.nc'
#etopodata = Dataset(url)

#topoin = etopodata.variables['ROSE'][:]
#lons = etopodata.variables['ETOPO05_X'][:]
#lats = etopodata.variables['ETOPO05_Y'][:]
# shift data so lons go from -180 to 180 instead of 20 to 380.
#topoin,lons = shiftgrid(180.,topoin,lons,start=False)

# plot topography/bathymetry as an image.

# create the figure and axes instances.
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
# setup of basemap ('lcc' = lambert conformal conic).
# use major and minor sphere radii from WGS84 ellipsoid.
m = Basemap(llcrnrlon=-145.5,llcrnrlat=1.,urcrnrlon=-2.566,urcrnrlat=46.352,\
            rsphere=(6378137.00,6356752.3142),\
            resolution='l',area_thresh=1000.,projection='lcc',\
            lat_1=50.,lon_0=-107.,ax=ax)
# transform to nx x ny regularly spaced 5km native projection grid
nx = int((m.xmax-m.xmin)/5000.)+1; ny = int((m.ymax-m.ymin)/5000.)+1
#topodat = m.transform_scalar(topoin,lons,lats,nx,ny)
# plot image over map with imshow.
#im = m.imshow(topodat,cm.GMT_haxby)
# draw coastlines and political boundaries.
m.drawcoastlines()
m.drawcountries()
#m.drawstates()
# draw parallels and meridians.
# label on left and bottom of map.
parallels = np.arange(0.,80,20.)
m.drawparallels(parallels,labels=[1,0,0,1])
meridians = np.arange(10.,360.,30.)
m.drawmeridians(meridians,labels=[1,0,0,1])
# add colorbar
#cb = m.colorbar(im,"right", size="5%", pad='2%')
ax.set_title('ETOPO5 Topography - Lambert Conformal Conic')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-20aec2a9ef3b> in <module>()
#       1 #http://matplotlib.org/basemap/api/basemap_api.html
#       2 get_ipython().magic('matplotlib inline')
# ----> 3 from mpl_toolkits.basemap import Basemap, shiftgrid, cm
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ImportError: No module named 'mpl_toolkits.basemap'

# %%
# Plotting points,lines polygones from shapefiles
#http://basemaptutorial.readthedocs.org/en/latest/shapefile.html
#http://download.geofabrik.de/europe/germany/berlin.html
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(llcrnrlon=11.5,llcrnrlat=52.,urcrnrlon=14.,urcrnrlat=55.,
             resolution='i', projection='tmerc', lat_0 = 52, lon_0 = 12.5)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#ddaa66',lake_color='aqua')
map.drawcoastlines()

# hier dann das shapefile angeben Pfad von der Platte
map.readshapefile('berlin-latest/railways', 'points')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-7d584c7edaef> in <module>()
#       3 #http://download.geofabrik.de/europe/germany/berlin.html
#       4 get_ipython().magic('matplotlib inline')
# ----> 5 from mpl_toolkits.basemap import Basemap
#       6 import matplotlib.pyplot as plt
#       7
#
# ImportError: No module named 'mpl_toolkits.basemap'

# %%
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

map = Basemap(projection='ortho', 
              lat_0=0, lon_0=45)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='aqua')
map.drawcoastlines()

x, y = map(0, 0) # Koordinaten in der jeweiligen Projektion berechnen!!! (Eingaben in Lon/Lat )

map.plot(x, y, marker='D',color='m')

plt.show()

# %%
#http://de.mathworks.com/help/map/examples/georeferencing-an-image-to-an-orthotile-base-layer.html?requestedDomain=www.mathworks.com
# vielleicht geht auch das ja

#http://introtopython.org/visualization_earthquakes.html

#http://basemaptutorial.readthedocs.org/en/latest/plotting_data.html

# %matplotlib inline
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# Make this plot larger.
plt.figure(figsize=(16,12))   # Stellt die Größe des Plots ein

map = Basemap(llcrnrlon=10,llcrnrlat=50.,urcrnrlon=15.,urcrnrlat=55.,
             resolution='i', projection='tmerc', lat_0 = 52, lon_0 = 12.5)

#map.drawmapboundary(fill_color='aqua')
#map.fillcontinents(color='#ddaa66',lake_color='aqua')

#map.bluemarble()   # Rasterdaten im Hintergrund anzeigen, weltweit Bluemarble Mosaik
map.shadedrelief()
map.drawcoastlines()
map.drawcountries()
parallels = np.arange(50.,60,1.)
map.drawparallels(parallels,labels=[1,0,0,1])
meridians = np.arange(0.,20.,2.)
map.drawmeridians(meridians,labels=[1,0,0,1])

# Einen Punkt zeichnen
lon = 13.3318
lat = 52.0799
x,y = map(lon, lat)  #damit werden die Längen und Breitengrade in Kartenkoordinaten umgerechnet 
map.plot(x, y, 'bo', markersize=6)

# mehrere Punkte zeichnen
lons = [13.53318, 11.8331, 13.46572]
lats = [51.0799, 52.894, 53.2399]
xs,ys = map(lons, lats)
map.plot(xs, ys, 'ro', markersize=4)

# Punkte mit Beschriftungen versehen
labels = ['Sitka', 'Baranof', 'Port Alexander']
for label, xpt, ypt in zip(labels, xs, ys):
    plt.text(xpt, ypt, label)
    #plt.text(xpt+10000, ypt+5000, label)   # um Labels etwas vom punkt entfernt zu plotten

# eine Linie zeichnen im Plot
lons1 = [11.1, 12.83, 13.1, 13.3]
lats1 = [51.9, 52.44, 53.2, 51.3]
xs1,ys1 = map(lons1, lats1)
map.plot(xs1, ys1, marker=None,color='m')


# ein geschlossenen Linienzug (Polygon) zeichnen im Plot
lons1 = [11.1, 11.3, 11.2, 11.1]
lats1 = [51.5, 51.3, 51.8, 51.5]
xs1,ys1 = map(lons1, lats1)
map.plot(xs1, ys1, marker=None,color='r')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-455d3979de68> in <module>()
#       7
#       8 get_ipython().magic('matplotlib inline')
# ----> 9 from mpl_toolkits.basemap import Basemap
#      10 import matplotlib.pyplot as plt
#      11
#
# ImportError: No module named 'mpl_toolkits.basemap'
